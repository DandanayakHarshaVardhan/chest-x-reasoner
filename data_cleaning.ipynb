# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd

IMAGE_ROOT = "/content/drive/MyDrive/DS3 (2)/archive/images/images_normalized"

# %%
image_extensions = (".png", ".jpg", ".jpeg", ".bmp")

image_files = []

for root, dirs, files in os.walk(IMAGE_ROOT):
    for file in files:
        if file.lower().endswith(image_extensions):
            image_files.append(file)

print(f"Total images found: {len(image_files)}")
# Out:
# Total images found: 5878

# %%
df_images = pd.DataFrame({"filename": image_files})
csv_path = "/content/drive/MyDrive/available_images.csv"
df_images.to_csv(csv_path, index=False)

print("Saved:", csv_path)
# Out:
# Saved: /content/drive/MyDrive/available_images.csv

# %%
df_images.head()
# Out:
#                     filename
# 0  3370_IM-1622-2001.dcm.png
# 1  3371_IM-1623-2001.dcm.png
# 2  3371_IM-1623-1001.dcm.png
# 3  3372_IM-1623-1001.dcm.png
# 4  3373_IM-1623-2001.dcm.png

# %%
#removing frontal and unwanted images from dataset

# %%
import pandas as pd

proj_path   = "/content/drive/MyDrive/DS3 (2)/archive/indiana_projections.csv"
report_path = "/content/drive/MyDrive/DS3 (2)/archive/indiana_reports.csv"

df_proj   = pd.read_csv(proj_path)
df_report = pd.read_csv(report_path)

print("Projections:", df_proj.shape)
print("Reports:", df_report.shape)
# Out:
# Projections: (7466, 3)
# Reports: (3851, 8)

# %%
df_frontal = df_proj[df_proj["projection"].str.lower() == "frontal"]

print("Frontal images:", df_frontal.shape)
# Out:
# Frontal images: (3818, 3)

# %%
df_merged = df_frontal.merge(
    df_report,
    on="uid",
    how="inner"
)

print("Merged samples:", df_merged.shape)
# Out:
# Merged samples: (3818, 10)

# %%
df_final = df_merged[[
    "uid",
    "filename",
    "projection",
    "findings",
    "impression"
]]

# %%
out_path = "/content/drive/MyDrive/indiana_frontal_with_reports.csv"
df_final.to_csv(out_path, index=False)

print("Saved:", out_path)
# Out:
# Saved: /content/drive/MyDrive/indiana_frontal_with_reports.csv

# %%
#creating 7 labeled dataset from reports

# %%
import pandas as pd
import re

csv_path = "/content/drive/MyDrive/indiana_frontal_with_reports.csv"
df = pd.read_csv(csv_path)

print("Total samples:", len(df))
df.head()
# Out:
# Total samples: 3818
#    uid                   filename projection  \
# 0    1     1_IM-0001-4001.dcm.png    Frontal
# 1    2     2_IM-0652-1001.dcm.png    Frontal
# 2    3     3_IM-1384-1001.dcm.png    Frontal
# 3    4     4_IM-2050-1001.dcm.png    Frontal
# 4    5  5_IM-2117-1003002.dcm.png    Frontal
#
#                                             findings  \
# 0  The cardiac silhouette and mediastinum size ar...
# 1  Borderline cardiomegaly. Midline sternotomy XX...
# 2                                                NaN
# 3  There are diffuse bilateral interstitial and a...
# 4  The cardiomediastinal silhouette and pulmonary...
#
#                                           impression
# 0                               Normal chest x-XXXX.
# 1                       No acute pulmonary findings.
# 2  No displaced rib fractures, pneumothorax, or p...
# 3  1. Bullous emphysema and interstitial fibrosis...
# 4              No acute cardiopulmonary abnormality.

# %%
def combine_text(row):
    if isinstance(row["findings"], str) and row["findings"].strip():
        return row["findings"]
    elif isinstance(row["impression"], str):
        return row["impression"]
    else:
        return ""

df["report_text"] = df.apply(combine_text, axis=1)

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-z\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

df["report_text"] = df["report_text"].apply(clean_text)

# %%
KEYWORDS = {
    "lung_opacity": [
        "opacity", "opacities", "infiltrate", "infiltration", "airspace disease"
    ],
    "consolidation": [
        "consolidation", "airspace consolidation"
    ],
    "pleural_effusion": [
        "pleural effusion", "effusions"
    ],
    "cardiomegaly": [
        "cardiomegaly", "enlarged heart", "cardiac enlargement"
    ],
    "atelectasis": [
        "atelectasis", "collapse", "hypoinflation"
    ],
    "edema": [
        "edema", "pulmonary edema", "interstitial edema"
    ],
    "support_devices": [
        "tube", "line", "catheter", "picc", "endotracheal", "chest tube"
    ]
}

# %%
def extract_labels(text):
    labels = {}
    for label, keywords in KEYWORDS.items():
        labels[label] = int(any(k in text for k in keywords))
    return pd.Series(labels)

labels_df = df["report_text"].apply(extract_labels)

# %%
final_df = pd.concat(
    [df[["filename"]], labels_df],
    axis=1
)

out_path = "/content/drive/MyDrive/final_training_labels.csv"
final_df.to_csv(out_path, index=False)

print("Saved final labels CSV:", out_path)
final_df.head()
# Out:
# Saved final labels CSV: /content/drive/MyDrive/final_training_labels.csv
#                     filename  lung_opacity  consolidation  pleural_effusion  \
# 0     1_IM-0001-4001.dcm.png             0              1                 1
# 1     2_IM-0652-1001.dcm.png             0              0                 0
# 2     3_IM-1384-1001.dcm.png             0              0                 1
# 3     4_IM-2050-1001.dcm.png             1              0                 1
# 4  5_IM-2117-1003002.dcm.png             0              1                 1
#
#    cardiomegaly  atelectasis  edema  support_devices
# 0             0            0      1                0
# 1             1            0      0                1
# 2             0            0      0                0
# 3             0            0      0                0
# 4             0            0      0                0

# %%
labels_df.sum().sort_values(ascending=False)
# Out:
# pleural_effusion    2514
# lung_opacity        1423
# consolidation       1183
# edema                292
# atelectasis          285
# support_devices      277
# cardiomegaly         188
# dtype: int64

# %%
import pandas as pd

CSV_PATH = "/content/drive/MyDrive/final_training_labels_clean.csv"
IMAGE_ROOT = "/content/drive/MyDrive/DS3 (2)/archive/images/images_normalized"

# Load CSV
df = pd.read_csv(CSV_PATH)

# Build image filename set
import os
image_filenames = set()
for root, _, files in os.walk(IMAGE_ROOT):
    for f in files:
        if f.lower().endswith((".png", ".jpg", ".jpeg")):
            image_filenames.add(f)

# Filter CSV to only existing images
df_filtered = df[df["filename"].isin(image_filenames)]

print("Final usable samples:", len(df_filtered))

# Save final locked CSV
FINAL_CSV = "/content/drive/MyDrive/final_training_labels_LOCKED.csv"
df_filtered.to_csv(FINAL_CSV, index=False)

print("✅ Locked training CSV saved:", FINAL_CSV)
# Out:
# Final usable samples: 3002
# ✅ Locked training CSV saved: /content/drive/MyDrive/final_training_labels_LOCKED.csv
